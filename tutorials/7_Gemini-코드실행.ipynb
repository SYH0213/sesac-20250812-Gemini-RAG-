# %% [markdown]
# ### 코드 실행 사용 설정

# %%
from google import genai
from google.genai import types

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="""이차방정식의 근을 구하는 파이썬 코드를 작성해줘. 
    예를 들어, ax^2 + bx + c = 0 형태의 방정식에서 a, b, c는 정수로 주어질 수 있어.
    이 코드가 올바르게 작동하는지 확인하기 위해 몇 가지 예시를 사용해서 실행해줘.""",
    
    config=types.GenerateContentConfig(
        tools=[types.Tool(code_execution=types.ToolCodeExecution)]
    ),
)

for part in response.candidates[0].content.parts:
    if part.text is not None:
        print(part.text)
    if part.executable_code is not None:
        print(part.executable_code.code)
    if part.code_execution_result is not None:
        print(part.code_execution_result.output)
# Out:
# 이차방정식 $ax^2 + bx + c = 0$ 의 근을 구하는 파이썬 코드를 작성해 드릴 수 있습니다. 이 문제에 가장 적합하고 정확한 방법은 `sympy` 라이브러리의 `solve` 함수를 사용하는 것입니다. `sympy`는 심볼릭 연산을 위한 라이브러리로, 대수 방정식을 풀고 복소수 근까지 정확하게 처리할 수 있습니다.
#
# ### 이차방정식 근을 구하는 파이썬 코드
#
# 아래 코드는 `a`, `b`, `c` 값을 입력받아 이차방정식의 근을 계산하고 반환합니다.
#
#
# ```python
# import sympy
#
# def solve_quadratic_equation(a, b, c):
#     """
#     이차방정식 ax^2 + bx + c = 0 의 근을 계산합니다.
#
#     Args:
#         a (int or float): x^2 항의 계수
#         b (int or float): x 항의 계수
#         c (int or float): 상수항
#
#     Returns:
#         list: 방정식의 근 (실수 또는 복소수)
#     """
#     # x를 심볼로 정의
#     x = sympy.Symbol('x')
#
#     # 방정식 정의
#     equation = a*x**2 + b*x + c
#
#     # 방정식의 근을 계산
#     roots = sympy.solve(equation, x)
#
#     return roots
#
# # 예시 실행을 위한 코드
# print("--- 이차방정식 근 계산 예시 ---")
#
# # 예시 1: 두 개의 서로 다른 실근 (x^2 - 5x + 6 = 0  => x=2, x=3)
# print("\n예시 1: x^2 - 5x + 6 = 0")
# roots1 = solve_quadratic_equation(1, -5, 6)
# print(f"근: {roots1}")
#
# # 예시 2: 하나의 실근 (중근) (x^2 - 4x + 4 = 0 => x=2)
# print("\n예시 2: x^2 - 4x + 4 = 0")
# roots2 = solve_quadratic_equation(1, -4, 4)
# print(f"근: {roots2}")
#
# # 예시 3: 두 개의 복소수 근 (x^2 + 1 = 0 => x=i, x=-i)
# print("\n예시 3: x^2 + 1 = 0")
# roots3 = solve_quadratic_equation(1, 0, 1)
# print(f"근: {roots3}")
#
# # 예시 4: a=0인 경우 (선형 방정식: 2x + 4 = 0 => x=-2)
# print("\n예시 4: 2x + 4 = 0 (a=0)")
# roots4 = solve_quadratic_equation(0, 2, 4)
# print(f"근: {roots4}")
#
# # 예시 5: 계수가 부동소수점인 경우
# print("\n예시 5: 0.5x^2 - 1.5x - 2 = 0")
# roots5 = solve_quadratic_equation(0.5, -1.5, -2)
# print(f"근: {roots5}")
#
# # 예시 6: 계수가 음수인 경우
# print("\n예시 6: -x^2 + 5x - 6 = 0")
# roots6 = solve_quadratic_equation(-1, 5, -6)
# print(f"근: {roots6}")
# ```
#
#
# ### 코드 설명
#
# 1.  **`import sympy`**: `sympy` 라이브러리를 임포트합니다.
# 2.  **`solve_quadratic_equation(a, b, c)` 함수**:
#     *   `x = sympy.Symbol('x')`: 방정식의 미지수 `x`를 `sympy` 심볼로 정의합니다.
#     *   `equation = a*x**2 + b*x + c`: 입력받은 `a`, `b`, `c` 값을 이용하여 `sympy` 방정식 객체를 생성합니다.
#     *   `roots = sympy.solve(equation, x)`: `sympy.solve()` 함수는 주어진 `equation`에서 `x`에 대한 해를 찾아 반환합니다. 이 함수는 자동으로 근의 판별식($b^2 - 4ac$)을 고려하여 실근, 중근, 복소수 근 등 모든 경우를 처리합니다. 또한, `a`가 0인 경우(선형 방정식)도 자연스럽게 처리합니다.
#     *   `return roots`: 계산된 근의 리스트를 반환합니다.
#
# ### 실행 예시 및 결과
#
# 제공된 예시들을 위 코드를 사용하여 실행한 결과는 다음과 같습니다.
#
#
# import sympy
#
# def solve_quadratic_equation(a, b, c):
#     x = sympy.Symbol('x')
#     equation = a*x**2 + b*x + c
#     roots = sympy.solve(equation, x)
#     return roots
#
# print("--- 이차방정식 근 계산 예시 ---")
#
# print("\n예시 1: x^2 - 5x + 6 = 0")
# roots1 = solve_quadratic_equation(1, -5, 6)
# print(f"근: {roots1}")
#
# print("\n예시 2: x^2 - 4x + 4 = 0")
# roots2 = solve_quadratic_equation(1, -4, 4)
# print(f"근: {roots2}")
#
# print("\n예시 3: x^2 + 1 = 0")
# roots3 = solve_quadratic_equation(1, 0, 1)
# print(f"근: {roots3}")
#
# print("\n예시 4: 2x + 4 = 0 (a=0)")
# roots4 = solve_quadratic_equation(0, 2, 4)
# print(f"근: {roots4}")
#
# print("\n예시 5: 0.5x^2 - 1.5x - 2 = 0")
# roots5 = solve_quadratic_equation(0.5, -1.5, -2)
# print(f"근: {roots5}")
#
# print("\n예시 6: -x^2 + 5x - 6 = 0")
# roots6 = solve_quadratic_equation(-1, 5, -6)
# print(f"근: {roots6}")
#
# --- 이차방정식 근 계산 예시 ---
#
# 예시 1: x^2 - 5x + 6 = 0
# 근: [2, 3]
#
# 예시 2: x^2 - 4x + 4 = 0
# 근: [2]
#
# 예시 3: x^2 + 1 = 0
# 근: [-I, I]
#
# 예시 4: 2x + 4 = 0 (a=0)
# 근: [-2]
#
# 예시 5: 0.5x^2 - 1.5x - 2 = 0
# 근: [-1.00000000000000, 4.00000000000000]
#
# 예시 6: -x^2 + 5x - 6 = 0
# 근: [2, 3]
#
# ### 결과 분석
#
# *   **예시 1 (x^2 - 5x + 6 = 0)**: 예상대로 `[2, 3]`이라는 두 개의 실근을 정확히 반환했습니다.
# *   **예시 2 (x^2 - 4x + 4 = 0)**: 예상대로 `[2]`라는 하나의 중근을 반환했습니다.
# *   **예시 3 (x^2 + 1 = 0)**: 예상대로 `[-I, I]`라는 두 개의 복소수 근(여기서 `I`는 허수 단위)을 정확히 반환했습니다. `sympy`는 복소수 근을 자동으로 처리합니다.
# *   **예시 4 (2x + 4 = 0)**: `a=0`인 경우, `sympy.solve`는 이를 선형 방정식으로 인식하여 `[-2]`라는 올바른 해를 반환했습니다.
# *   **예시 5 (0.5x^2 - 1.5x - 2 = 0)**: 부동소수점 계수도 정확하게 처리하여 `[-1.0, 4.0]`을 반환했습니다.
# *   **예시 6 (-x^2 + 5x - 6 = 0)**: 계수가 음수인 경우에도 올바른 근 `[2, 3]`을 반환했습니다.
#
# 이 코드는 `sympy`를 사용하여 다양한 형태의 이차방정식(및 선형 방정식)의 근을 정확하고 안정적으로 계산할 수 있음을 보여줍니다.

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""1부터 100까지의 합을 계산하는 파이썬 코드를 생성하고 실행하겠습니다.
#
# **계산을 위한 파이썬 코드:**
#
# """
#           ),
#           Part(
#             text="""```python
# # 1부터 100까지의 합을 계산하는 코드
# total_sum = 0
# for i in range(1, 101):
#     total_sum += i
# print(f"1부터 100까지의 합: {total_sum}")
# ```"""
#           ),
#           Part(
#             text="""
#
# **코드 실행 및 결과 확인:**
#
# """
#           ),
#           Part(
#             executable_code=ExecutableCode(
#               code=<... Max depth ...>,
#               language=<... Max depth ...>
#             )
#           ),
#           Part(
#             code_execution_result=CodeExecutionResult(
#               outcome=<... Max depth ...>,
#               output=<... Max depth ...>
#             )
#           ),
#           <... 1 more items ...>,
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='Dp2aaKDQLfHUz7IPssXB-QU',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=276,
#     prompt_token_count=45,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=45
#       ),
#     ],
#     thoughts_token_count=181,
#     tool_use_prompt_token_count=412,
#     tool_use_prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=412
#       ),
#     ],
#     total_token_count=914
#   )
# )

# %%
response.candidates[0]
# Out:
# Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="""1부터 100까지의 합을 계산하는 파이썬 코드를 생성하고 실행하겠습니다.
#
# **계산을 위한 파이썬 코드:**
#
# """
#       ),
#       Part(
#         text="""```python
# # 1부터 100까지의 합을 계산하는 코드
# total_sum = 0
# for i in range(1, 101):
#     total_sum += i
# print(f"1부터 100까지의 합: {total_sum}")
# ```"""
#       ),
#       Part(
#         text="""
#
# **코드 실행 및 결과 확인:**
#
# """
#       ),
#       Part(
#         executable_code=ExecutableCode(
#           code="""# 1부터 100까지의 합을 계산하는 코드
# total_sum = 0
# for i in range(1, 101):
#     total_sum += i
# print(f"1부터 100까지의 합: {total_sum}")
# """,
#           language=<Language.PYTHON: 'PYTHON'>
#         )
#       ),
#       Part(
#         code_execution_result=CodeExecutionResult(
#           outcome=<Outcome.OUTCOME_OK: 'OUTCOME_OK'>,
#           output="""1부터 100까지의 합: 5050
# """
#         )
#       ),
#       <... 1 more items ...>,
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )

# %%
response.candidates[0].content.parts
# Out:
# [Part(
#    text="""1부터 100까지의 합을 계산하는 파이썬 코드를 생성하고 실행하겠습니다.
#
#  **계산을 위한 파이썬 코드:**
#
#  """
#  ),
#  Part(
#    text="""```python
#  # 1부터 100까지의 합을 계산하는 코드
#  total_sum = 0
#  for i in range(1, 101):
#      total_sum += i
#  print(f"1부터 100까지의 합: {total_sum}")
#  ```"""
#  ),
#  Part(
#    text="""
#
#  **코드 실행 및 결과 확인:**
#
#  """
#  ),
#  Part(
#    executable_code=ExecutableCode(
#      code="""# 1부터 100까지의 합을 계산하는 코드
#  total_sum = 0
#  for i in range(1, 101):
#      total_sum += i
#  print(f"1부터 100까지의 합: {total_sum}")
#  """,
#      language=<Language.PYTHON: 'PYTHON'>
#    )
#  ),
#  Part(
#    code_execution_result=CodeExecutionResult(
#      outcome=<Outcome.OUTCOME_OK: 'OUTCOME_OK'>,
#      output="""1부터 100까지의 합: 5050
#  """
#    )
#  ),
#  Part(
#    text="""**확인:**
#
#  1부터 100까지의 합은 `5050`으로 올바르게 계산되었습니다. 이는 등차수열의 합 공식 `n * (n + 1) / 2` (여기서 n=100)을 사용하여 `100 * (100 + 1) / 2 = 100 * 101 / 2 = 5050`으로 수동으로 계산한 값과 일치합니다."""
#  )]
